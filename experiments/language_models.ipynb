# %% [markdown]
# ## Install requirements

# %%
# !pip install -U -q datasets transformers evaluate torch torchinfo pytorch-lightning tokenizers sentencepiece huggingface_hub
# Out:
#      |████████████████████████████████| 441 kB 8.4 MB/s
#      |████████████████████████████████| 5.3 MB 58.0 MB/s
#      |████████████████████████████████| 72 kB 1.4 MB/s
#      |████████████████████████████████| 708 kB 69.3 MB/s
#      |████████████████████████████████| 7.6 MB 53.1 MB/s
#      |████████████████████████████████| 1.3 MB 36.9 MB/s
#      |████████████████████████████████| 163 kB 69.7 MB/s
#      |████████████████████████████████| 212 kB 57.5 MB/s
#      |████████████████████████████████| 115 kB 11.5 MB/s
#      |████████████████████████████████| 127 kB 56.3 MB/s
#      |████████████████████████████████| 529 kB 51.5 MB/s

# %%
# !nvidia-smi
# Out:
# Sun Oct 16 16:53:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Imports

# %%
import torch
import pandas as pd
from transformers import PreTrainedTokenizerFast, EarlyStoppingCallback, AutoConfig, AutoModelForCausalLM, AutoTokenizer, TextClassificationPipeline, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding
from datasets import Dataset, DatasetDict, ClassLabel, Value, load_dataset
from transformers.pipelines.pt_utils import KeyDataset
import numpy as np
from torchinfo import summary
from tokenizers import ByteLevelBPETokenizer
from tqdm import tqdm
import evaluate
from huggingface_hub import notebook_login

# %%
IS_CUDA_AVAILABLE = torch.cuda.is_available()
IS_CUDA_AVAILABLE
# Out:
# True

# %%
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %% [markdown]
# ## Load datasets and create hf 🤗 `Dataset`

# %%
ds = load_dataset(
    'csv', 
    data_files={'train': 'train.csv', 'val': 'val.csv', 'test': 'test.csv'}
)

cl = ClassLabel(names=list(ds['train'].unique('label')))
ds = ds.cast_column('label', cl).remove_columns(['label_sentiment'])

ds
# Out:
# WARNING:datasets.builder:Using custom data configuration default-ce5e8dfc34ae613f
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-ce5e8dfc34ae613f/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-ce5e8dfc34ae613f/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'id', 'text'],
#         num_rows: 4220
#     })
#     val: Dataset({
#         features: ['label', 'id', 'text'],
#         num_rows: 880
#     })
#     test: Dataset({
#         features: ['label', 'id', 'text'],
#         num_rows: 900
#     })
# })

# %%
ds['test'].features
# Out:
# {'label': ClassLabel(names=['dvd', 'books', 'camera', 'health', 'software', 'music'], id=None),
#  'id': Value(dtype='string', id=None),
#  'text': Value(dtype='string', id=None)}

# %% [markdown]
# ## Encoder only models

# %% [markdown]
# ### Select model

# %%
# select one of the models to finetune

# model_name = 'bert-base-uncased'
# model_name = 'xlm-roberta-base'
# model_name = 'albert-base-v2'
model_name = 'distilbert-base-uncased'

# %% [markdown]
# ### Preprocess data

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True)

tokenized_ds = ds.map(tokenize_function, batched=True)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'id', 'text', 'input_ids', 'attention_mask'],
#         num_rows: 4220
#     })
#     val: Dataset({
#         features: ['label', 'id', 'text', 'input_ids', 'attention_mask'],
#         num_rows: 880
#     })
#     test: Dataset({
#         features: ['label', 'id', 'text', 'input_ids', 'attention_mask'],
#         num_rows: 900
#     })
# })

# %% [markdown]
# ### Create model

# %%
# load pretrained model from HuggingFace Model Hub
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=cl.num_classes)
# Out:
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# freeze some layers if needed 

# for name, param in model.named_parameters():
#     if 'embeddings' in name:
#         param.requires_grad = False

#     if 'encoder' in name:
#         param.requires_grad = False

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              23,440,896
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           4,614
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 66,958,086
# Trainable params: 66,958,086
# Non-trainable params: 0
# ================================================================================

# %% [markdown]
# ### Evaluation functions

# %%
# create matrics function 

metric_acc = evaluate.load('accuracy')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric_acc.compute(predictions=predictions, references=labels)
# Out:
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %% [markdown]
# ### Train model

# %%
# create training args and run training 
# train on train data, validate on val data =)

training_args = TrainingArguments(
    output_dir="./results",
    report_to='all',
    learning_rate=5e-6,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=4,
    weight_decay=0.01,
    no_cuda=not IS_CUDA_AVAILABLE,
    # bf16=IS_CUDA_AVAILABLE,
    fp16=IS_CUDA_AVAILABLE,
    evaluation_strategy='epoch',
    logging_strategy='epoch',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds['train'],
    eval_dataset=tokenized_ds['val'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()

# %% [markdown]
# ### Validate trained model

# %%
trainer.predict(tokenized_ds['test'])[-1]
# Out:
# The following columns in the test set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text, id. If text, id are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 900
#   Batch size = 32
#     <div>
#
#       <progress value='567' max='1056' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 567/1056 03:05 < 02:40, 3.05 it/s, Epoch 2.14/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.066800</td>
#       <td>0.244372</td>
#       <td>0.939773</td>
#       <td>0.939408</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.046900</td>
#       <td>0.258450</td>
#       <td>0.942045</td>
#       <td>0.941744</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='29' max='29' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [29/29 00:05]
#     </div>
# {'test_loss': 0.2570228576660156,
#  'test_accuracy': 0.9433333333333334,
#  'test_f1': 0.9432863785846166,
#  'test_runtime': 5.5329,
#  'test_samples_per_second': 162.663,
#  'test_steps_per_second': 5.241}

# %% [markdown]
# ### Push to hub

# %%
id2label = {cl.str2int(i): i for i in cl.names}
label2id = {v: k for k, v in id2label.items()}
id2label
# Out:
# {0: 'dvd', 1: 'books', 2: 'camera', 3: 'health', 4: 'software', 5: 'music'}

# %%
model.config.update({
    'id2label': id2label,
    'label2id': label2id,
})
model.config
# Out:
# DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "dvd",
#     "1": "books",
#     "2": "camera",
#     "3": "health",
#     "4": "software",
#     "5": "music"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "books": 1,
#     "camera": 2,
#     "dvd": 0,
#     "health": 3,
#     "music": 5,
#     "software": 4
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "vocab_size": 30522
# }

# %%
hub_name = 'distilbert-base-uncased-reviews-finetuned'
tokenizer.push_to_hub(hub_name)
model.push_to_hub(hub_name)
# Out:
# tokenizer config file saved in /tmp/tmp2neppujh/tokenizer_config.json
# Special tokens file saved in /tmp/tmp2neppujh/special_tokens_map.json
# Uploading the following files to k4black/distilbert-base-uncased-reviews-finetuned: tokenizer.json,special_tokens_map.json,tokenizer_config.json,vocab.txt
# Configuration saved in /tmp/tmp9d142mgt/config.json
# Model weights saved in /tmp/tmp9d142mgt/pytorch_model.bin
# Uploading the following files to k4black/distilbert-base-uncased-reviews-finetuned: pytorch_model.bin,config.json
# CommitInfo(commit_url='https://huggingface.co/k4black/distilbert-base-uncased-reviews-finetuned/commit/9574a1005ce3ab3712bd3a050685e8ec83ba8c99', commit_message='Upload DistilBertForSequenceClassification', commit_description='', oid='9574a1005ce3ab3712bd3a050685e8ec83ba8c99', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Training LM from scratch

# %%
model_name = 'roberta-base'

# %% [markdown]
# ### Train tokenizer

# %%
unique_words = set()
for text in ds['train']['text']:
    unique_words.update(text.split())
len(unique_words)
# Out:
# 32420

# %%
# load pretrained to copy settings 
old_tokenizer = AutoTokenizer.from_pretrained(model_name)
old_tokenizer
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# PreTrainedTokenizerFast(name_or_path='roberta-base', vocab_size=50265, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=False)})

# %%
tokenizer = old_tokenizer.train_new_from_iterator(
    ds['train']['text'], 
    show_progress=True,
    vocab_size=25_000, 
)
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='roberta-base', vocab_size=25000, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=False)})

# %%
tokenizer('I love you')
# Out:
# {'input_ids': [0, 45, 712, 327, 2], 'attention_mask': [1, 1, 1, 1, 1]}

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/drive/MyDrive/custom-model.zip custom-model.zip
# !unzip custom-model.zip

# %%
tokenizer = AutoTokenizer.from_pretrained('custom-model')

# %% [markdown]
# ### Preprocess data

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True)

tokenized_ds = ds.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
def group_texts(examples):
    examples["label"] = examples["input_ids"].copy()
    return examples

# %%
lm_datasets = tokenized_ds.remove_columns(['label']).map(
    group_texts,
    batched=True,
)
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# ### Create model

# %%
config = AutoConfig.from_pretrained(model_name)
model = AutoModelForCausalLM.from_config(config)
# Out:
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`

# %%
model = AutoModelForCausalLM.from_pretrained('custom-model')
# Out:
# loading configuration file custom-model/config.json
# Model config RobertaConfig {
#   "_name_or_path": "custom-model",
#   "architectures": [
#     "RobertaForCausalLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file custom-model/pytorch_model.bin
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# All model checkpoint weights were used when initializing RobertaForCausalLM.
#
# All the weights of RobertaForCausalLM were initialized from the model checkpoint at custom-model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForCausalLM for predictions without further training.

# %%
summary(model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# RobertaForCausalLM                                           --
# ├─RobertaModel: 1-1                                          --
# │    └─RobertaEmbeddings: 2-1                                --
# │    │    └─Embedding: 3-1                                   38,603,520
# │    │    └─Embedding: 3-2                                   394,752
# │    │    └─Embedding: 3-3                                   768
# │    │    └─LayerNorm: 3-4                                   1,536
# │    │    └─Dropout: 3-5                                     --
# │    └─RobertaEncoder: 2-2                                   --
# │    │    └─ModuleList: 3-6                                  85,054,464
# ├─RobertaLMHead: 1-2                                         --
# │    └─Linear: 2-3                                           590,592
# │    └─LayerNorm: 2-4                                        1,536
# │    └─Linear: 2-5                                           38,653,785
# =====================================================================================
# Total params: 124,697,433
# Trainable params: 124,697,433
# Non-trainable params: 0
# =====================================================================================

# %% [markdown]
# ### Train LM

# %%
training_args = TrainingArguments(
    output_dir="./results-lm/",
    report_to='all',
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    num_train_epochs=32,
    weight_decay=0.01,
    no_cuda=not IS_CUDA_AVAILABLE,
    # bf16=IS_CUDA_AVAILABLE,
    fp16=IS_CUDA_AVAILABLE,
    logging_strategy='steps',
    logging_steps=100,
    evaluation_strategy='steps',
    eval_steps=100,
    metric_for_best_model='eval_loss',
    load_best_model_at_end=True,
    save_total_limit=5,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets['train'],
    eval_dataset=lm_datasets['val'],
    tokenizer=tokenizer,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

trainer.train()
# Out:
# Using cuda_amp half precision backend
# The following columns in the training set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 4220
#   Num Epochs = 32
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 16896
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='16896' max='16896' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16896/16896 3:01:36, Epoch 32/32]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.720800</td>
#       <td>0.791032</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.703800</td>
#       <td>0.756890</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.716300</td>
#       <td>0.723797</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.656600</td>
#       <td>0.695602</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.688600</td>
#       <td>0.667445</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.614100</td>
#       <td>0.640812</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.564000</td>
#       <td>0.609810</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.560500</td>
#       <td>0.575085</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.574100</td>
#       <td>0.537643</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.497400</td>
#       <td>0.505667</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.476500</td>
#       <td>0.480290</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.443400</td>
#       <td>0.457112</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.422200</td>
#       <td>0.435910</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.455700</td>
#       <td>0.413251</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.398200</td>
#       <td>0.391106</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.359400</td>
#       <td>0.369438</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.362400</td>
#       <td>0.349576</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.321600</td>
#       <td>0.330143</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.318500</td>
#       <td>0.310073</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.318500</td>
#       <td>0.289977</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.305700</td>
#       <td>0.273562</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.256700</td>
#       <td>0.259064</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.275700</td>
#       <td>0.246280</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.261900</td>
#       <td>0.231625</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.238400</td>
#       <td>0.219947</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.236100</td>
#       <td>0.208871</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.208300</td>
#       <td>0.199746</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.214400</td>
#       <td>0.190610</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.200500</td>
#       <td>0.181707</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.197900</td>
#       <td>0.173005</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.189700</td>
#       <td>0.165257</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.176800</td>
#       <td>0.157976</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.165800</td>
#       <td>0.151895</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.171000</td>
#       <td>0.145330</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.159200</td>
#       <td>0.139746</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.162700</td>
#       <td>0.133333</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.146600</td>
#       <td>0.127520</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.142500</td>
#       <td>0.122553</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.137800</td>
#       <td>0.117846</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.125500</td>
#       <td>0.112872</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.131700</td>
#       <td>0.108512</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.126900</td>
#       <td>0.104257</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.115600</td>
#       <td>0.100745</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.117000</td>
#       <td>0.097283</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.118500</td>
#       <td>0.093625</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.101500</td>
#       <td>0.090173</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.110000</td>
#       <td>0.086983</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.090800</td>
#       <td>0.083977</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.100800</td>
#       <td>0.080901</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.090700</td>
#       <td>0.078088</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.085200</td>
#       <td>0.075675</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.093000</td>
#       <td>0.073060</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.087700</td>
#       <td>0.069590</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.082100</td>
#       <td>0.067762</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.075000</td>
#       <td>0.065484</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.080500</td>
#       <td>0.063156</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.072200</td>
#       <td>0.061007</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.072600</td>
#       <td>0.059251</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.067100</td>
#       <td>0.056971</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.071200</td>
#       <td>0.055319</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.065000</td>
#       <td>0.053565</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.059600</td>
#       <td>0.051929</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.058900</td>
#       <td>0.050158</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.057700</td>
#       <td>0.048894</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.054600</td>
#       <td>0.047317</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.056300</td>
#       <td>0.046268</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.050600</td>
#       <td>0.044803</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.055100</td>
#       <td>0.043473</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.048600</td>
#       <td>0.042081</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.045600</td>
#       <td>0.040770</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.050300</td>
#       <td>0.040059</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.042100</td>
#       <td>0.038767</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.043800</td>
#       <td>0.037937</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.043700</td>
#       <td>0.036633</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.041500</td>
#       <td>0.035794</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.040100</td>
#       <td>0.035012</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.038700</td>
#       <td>0.034168</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.038500</td>
#       <td>0.033182</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.033600</td>
#       <td>0.032536</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.033200</td>
#       <td>0.031947</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.032600</td>
#       <td>0.031127</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.031400</td>
#       <td>0.030400</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.034400</td>
#       <td>0.029693</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.032000</td>
#       <td>0.028948</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.031900</td>
#       <td>0.028430</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.028500</td>
#       <td>0.027838</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.027400</td>
#       <td>0.027285</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.028300</td>
#       <td>0
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-500
# Configuration saved in ./results-lm/checkpoint-500/config.json
# Model weights saved in ./results-lm/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-1000
# Configuration saved in ./results-lm/checkpoint-1000/config.json
# Model weights saved in ./results-lm/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-1500
# Configuration saved in ./results-lm/checkpoint-1500/config.json
# Model weights saved in ./results-lm/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-1500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-2000
# Configuration saved in ./results-lm/checkpoint-2000/config.json
# Model weights saved in ./results-lm/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-2500
# Configuration saved in ./results-lm/checkpoint-2500/config.json
# Model weights saved in ./results-lm/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-3000
# Configuration saved in ./results-lm/checkpoint-3000/config.json
# Model weights saved in ./results-lm/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-3500
# Configuration saved in ./results-lm/checkpoint-3500/config.json
# Model weights saved in ./results-lm/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-4000
# Configuration saved in ./results-lm/checkpoint-4000/config.json
# Model weights saved in ./results-lm/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-4500
# Configuration saved in ./results-lm/checkpoint-4500/config.json
# Model weights saved in ./results-lm/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-5000
# Configuration saved in ./results-lm/checkpoint-5000/config.json
# Model weights saved in ./results-lm/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-5500
# Configuration saved in ./results-lm/checkpoint-5500/config.json
# Model weights saved in ./results-lm/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-6000
# Configuration saved in ./results-lm/checkpoint-6000/config.json
# Model weights saved in ./results-lm/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-6500
# Configuration saved in ./results-lm/checkpoint-6500/config.json
# Model weights saved in ./results-lm/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-7000
# Configuration saved in ./results-lm/checkpoint-7000/config.json
# Model weights saved in ./results-lm/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-7500
# Configuration saved in ./results-lm/checkpoint-7500/config.json
# Model weights saved in ./results-lm/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-8000
# Configuration saved in ./results-lm/checkpoint-8000/config.json
# Model weights saved in ./results-lm/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-8500
# Configuration saved in ./results-lm/checkpoint-8500/config.json
# Model weights saved in ./results-lm/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-9000
# Configuration saved in ./results-lm/checkpoint-9000/config.json
# Model weights saved in ./results-lm/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-9500
# Configuration saved in ./results-lm/checkpoint-9500/config.json
# Model weights saved in ./results-lm/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ...
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-13000
# Configuration saved in ./results-lm/checkpoint-13000/config.json
# Model weights saved in ./results-lm/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-10500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-13500
# Configuration saved in ./results-lm/checkpoint-13500/config.json
# Model weights saved in ./results-lm/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-14000
# Configuration saved in ./results-lm/checkpoint-14000/config.json
# Model weights saved in ./results-lm/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-11500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-14500
# Configuration saved in ./results-lm/checkpoint-14500/config.json
# Model weights saved in ./results-lm/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-14500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-15000
# Configuration saved in ./results-lm/checkpoint-15000/config.json
# Model weights saved in ./results-lm/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-15000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-12500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-15500
# Configuration saved in ./results-lm/checkpoint-15500/config.json
# Model weights saved in ./results-lm/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-15500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-16000
# Configuration saved in ./results-lm/checkpoint-16000/config.json
# Model weights saved in ./results-lm/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-16000/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-13500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# Saving model checkpoint to ./results-lm/checkpoint-16500
# Configuration saved in ./results-lm/checkpoint-16500/config.json
# Model weights saved in ./results-lm/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in ./results-lm/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./results-lm/checkpoint-16500/special_tokens_map.json
# Deleting older checkpoint [results-lm/checkpoint-14000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./results-lm/checkpoint-16500 (score: 0.014477109536528587).
# TrainOutput(global_step=16896, training_loss=0.10809235852635042, metrics={'train_runtime': 10899.9015, 'train_samples_per_second': 12.389, 'train_steps_per_second': 1.55, 'total_flos': 3.555136816349184e+16, 'train_loss': 0.10809235852635042, 'epoch': 32.0})

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForCausalLM.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForCausalLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 16
#     <div>
#
#       <progress value='55' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [55/55 00:15]
#     </div>
# {'eval_loss': 0.014477109536528587,
#  'eval_runtime': 16.0399,
#  'eval_samples_per_second': 54.863,
#  'eval_steps_per_second': 3.429,
#  'epoch': 32.0}

# %% [markdown]
# ### Save model and push to hub

# %%
trainer.save_model('custom-model')
# Out:
# Saving model checkpoint to custom-model
# Configuration saved in custom-model/config.json
# Model weights saved in custom-model/pytorch_model.bin
# tokenizer config file saved in custom-model/tokenizer_config.json
# Special tokens file saved in custom-model/special_tokens_map.json

# %%
# !rm -rf custom-model.zip
# !zip -r custom-model.zip custom-model

# %%
# !ls -lah
# Out:
# total 447M
# drwxr-xr-x 1 root root 4.0K Oct 13 18:04 .
# drwxr-xr-x 1 root root 4.0K Oct 13 14:55 ..
# drwxr-xr-x 4 root root 4.0K Oct  7 13:34 .config
# drwxr-xr-x 2 root root 4.0K Oct 13 12:12 custom-model
# -rw-r--r-- 1 root root 442M Oct 13 18:04 custom-model.zip
# drwx------ 5 root root 4.0K Oct 13 14:59 drive
# drwxr-xr-x 8 root root 4.0K Oct 13 17:59 results-lm
# drwxr-xr-x 1 root root 4.0K Oct  7 13:35 sample_data
# -rw-r--r-- 1 root root 701K Oct 13 14:57 test.csv
# -rw-r--r-- 1 root root 3.2M Oct 13 14:57 train.csv
# -rw-r--r-- 1 root root 669K Oct 13 14:57 val.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp custom-model.zip /content/drive/MyDrive
# !ls -lah | grep custom-model.zip

# %%
hub_name = 'roberta-reviews-lm'
tokenizer.push_to_hub(hub_name)
model.push_to_hub(hub_name)
# Out:
# tokenizer config file saved in /tmp/tmpyeidnpz8/tokenizer_config.json
# Special tokens file saved in /tmp/tmpyeidnpz8/special_tokens_map.json
# Uploading the following files to k4black/roberta-reviews-lm: merges.txt,vocab.json,tokenizer.json,special_tokens_map.json,tokenizer_config.json
# Configuration saved in /tmp/tmp8op61pzb/config.json
# Model weights saved in /tmp/tmp8op61pzb/pytorch_model.bin
# Uploading the following files to k4black/roberta-reviews-lm: pytorch_model.bin,config.json
# CommitInfo(commit_url='https://huggingface.co/k4black/roberta-reviews-lm/commit/6aaa5fd72e2a2424c514ec8c01ff7583014c8766', commit_message='Upload RobertaForCausalLM', commit_description='', oid='6aaa5fd72e2a2424c514ec8c01ff7583014c8766', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### Finetune with classification task

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/MyDrive/custom-model.zip custom-model.zip
# Out:
# Mounted at /content/drive

# %%
# !unzip custom-model.zip
# Out:
# Archive:  custom-model.zip
#    creating: custom-model/
#   inflating: custom-model/merges.txt
#   inflating: custom-model/vocab.json
#   inflating: custom-model/tokenizer.json
#   inflating: custom-model/training_args.bin
#   inflating: custom-model/special_tokens_map.json
#   inflating: custom-model/tokenizer_config.json
#   inflating: custom-model/config.json
#   inflating: custom-model/pytorch_model.bin

# %% [markdown]
# ### Process data

# %%
tokenizer = AutoTokenizer.from_pretrained('custom-model')
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True)

tokenized_ds = ds.map(tokenize_function, batched=True)
# Out:
# loading file vocab.json
# loading file merges.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# #### Create model

# %%
model = AutoModelForSequenceClassification.from_pretrained('custom-model', num_labels=cl.num_classes)
# Out:
# loading configuration file custom-model/config.json
# Model config RobertaConfig {
#   "_name_or_path": "custom-model",
#   "architectures": [
#     "RobertaForCausalLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file custom-model/pytorch_model.bin
# Some weights of the model checkpoint at custom-model were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at custom-model and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# freeze some layers
for name, param in model.named_parameters():
#     if 'embeddings' in name:
#         param.requires_grad = False

    if 'encoder' in name:
        param.requires_grad = False

# %%
summary(model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# RobertaForSequenceClassification                             --
# ├─RobertaModel: 1-1                                          --
# │    └─RobertaEmbeddings: 2-1                                --
# │    │    └─Embedding: 3-1                                   38,603,520
# │    │    └─Embedding: 3-2                                   394,752
# │    │    └─Embedding: 3-3                                   768
# │    │    └─LayerNorm: 3-4                                   1,536
# │    │    └─Dropout: 3-5                                     --
# │    └─RobertaEncoder: 2-2                                   --
# │    │    └─ModuleList: 3-6                                  (85,054,464)
# ├─RobertaClassificationHead: 1-2                             --
# │    └─Linear: 2-3                                           590,592
# │    └─Dropout: 2-4                                          --
# │    └─Linear: 2-5                                           4,614
# =====================================================================================
# Total params: 124,650,246
# Trainable params: 39,595,782
# Non-trainable params: 85,054,464
# =====================================================================================

# %% [markdown]
# #### Evaluational functions

# %%
# create matrics function 

metric_acc = evaluate.load('accuracy')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric_acc.compute(predictions=predictions, references=labels)

# %% [markdown]
# #### Train model

# %%
# create training args and run training 
# train on train data, validate on val data =)

training_args = TrainingArguments(
    output_dir="./results",
    report_to='all',
    learning_rate=1e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=8,
    weight_decay=0.01,
    no_cuda=not IS_CUDA_AVAILABLE,
    # bf16=IS_CUDA_AVAILABLE,
    fp16=IS_CUDA_AVAILABLE,
    evaluation_strategy='epoch',
    logging_strategy='epoch',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds['train'],
    eval_dataset=tokenized_ds['val'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# PyTorch: setting up devices
# Using cuda_amp half precision backend
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 4220
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2112
#     <div>
#
#       <progress value='1329' max='2112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1329/2112 12:17 < 07:15, 1.80 it/s, Epoch 5.03/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.792600</td>
#       <td>1.767094</td>
#       <td>0.230682</td>
#       <td>0.219178</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.766500</td>
#       <td>1.753293</td>
#       <td>0.225000</td>
#       <td>0.201646</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.749200</td>
#       <td>1.744324</td>
#       <td>0.227273</td>
#       <td>0.204233</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.734400</td>
#       <td>1.735245</td>
#       <td>0.234091</td>
#       <td>0.227024</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.722000</td>
#       <td>1.728845</td>
#       <td>0.237500</td>
#       <td>0.225881</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 32
# Saving model checkpoint to ./results/checkpoint-500
# Configuration saved in ./results/checkpoint-500/config.json
# Model weights saved in ./results/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 32
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 32
# Saving model checkpoint to ./results/checkpoint-1000
# Configuration saved in ./results/checkpoint-1000/config.json
# Model weights saved in ./results/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 32
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: id, text. If id, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 880
#   Batch size = 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a33f730150ea> in <module>
#      27 )
#      28
# ---> 29 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1502             resume_from_checkpoint=resume_from_checkpoint,
#    1503             trial=trial,
# -> 1504             ignore_keys_for_eval=ignore_keys_for_eval,
#    1505         )
#    1506
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1740                         tr_loss_step = self.training_step(model, inputs)
#    1741                 else:
# -> 1742                     tr_loss_step = self.training_step(model, inputs)
#    1743
#    1744                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2494
#    2495         if self.do_grad_scaling:
# -> 2496             self.scaler.scale(loss).backward()
#    2497         elif self.use_apex:
#    2498             with amp.scale_loss(loss, self.optimizer) as scaled_loss:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %% [markdown]
# #### Validate trained model

# %%
trainer.predict(tokenized_ds['test'])[-1]

# %% [markdown]
# ## Zero-Shot Classification

# %% [markdown]
# ### Select model

# %%
zs_model_name = 'facebook/bart-large-mnli'

# %% [markdown]
# ### Create pipeline

# %%
from transformers import pipeline

zs_model = pipeline('zero-shot-classification', model=zs_model_name, device=0)

# %%
# %%time
predict = []
for out in tqdm(zs_model(KeyDataset(ds['test'], 'text'), list(cl.names), batch_size=16), total=len(ds['test'])):
    predict.append(out['labels'][0])

len(predict)
# Out:
# 100%|██████████| 900/900 [09:35<00:00,  1.56it/s]
# CPU times: user 8min 53s, sys: 25.2 s, total: 9min 18s
# Wall time: 9min 35s
# 900

# %% [markdown]
# ### Evaluation

# %%
metric_f1 = evaluate.load('f1')
metric_acc = evaluate.load('accuracy')
# Out:
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
labels = KeyDataset(ds['test'], 'label')
_predict = [cl.str2int(p) for p in predict]
{
    **metric_acc.compute(predictions=_predict, references=labels),
    **metric_f1.compute(predictions=_predict, references=labels, average='macro'),
}
# Out:
# {'accuracy': 0.7511111111111111, 'f1': 0.7367648519861256}
