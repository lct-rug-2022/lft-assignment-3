# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sn
from sklearn import metrics

# %% [markdown]
# ## Load data and prediction

# %%
df = pd.read_csv('test.csv')
_pred = pd.read_csv('prediction.csv')
df['pred'] = _pred['label']
df['pred_score'] = _pred['score']

# %%
df
# Out:
#         label label_sentiment       id  \
# 0       music             neg  568.txt
# 1    software             neg  455.txt
# 2       books             pos  945.txt
# 3       books             pos  303.txt
# 4       books             neg    6.txt
# ..        ...             ...      ...
# 895     books             pos  627.txt
# 896  software             neg  280.txt
# 897     books             neg  325.txt
# 898     music             neg  100.txt
# 899    camera             neg  923.txt
#
#                                                   text      pred  pred_score
# 0    first they started out as nu-metal , then they...     music    0.997299
# 1    the program crashed during setup . when i fina...  software    0.995446
# 2    i also used this book in my graduate program ....     books    0.995472
# 3    a good thriller , that was very grisham . deli...       dvd    0.856511
# 4    why is it ever time you want something bad eno...     books    0.995410
# ...

# %% [markdown]
# ## Analysis

# %%
print(metrics.classification_report(df['label'], df['pred']))
# Out:
#               precision    recall  f1-score   support
#
#        books       0.98      0.97      0.97       149
#       camera       0.93      0.94      0.93       148
#          dvd       0.92      0.97      0.94       152
#       health       0.92      0.92      0.92       148
#        music       0.95      0.95      0.95       154
#     software       0.97      0.91      0.94       149
#
#     accuracy                           0.94       900
#    macro avg       0.94      0.94      0.94       900
# weighted avg       0.94      0.94      0.94       900

# %%
metrics.confusion_matrix(df['label'], df['pred'])
# Out:
# array([[144,   0,   4,   1,   0,   0],
#        [  1, 139,   2,   5,   0,   1],
#        [  2,   0, 147,   0,   3,   0],
#        [  0,   6,   0, 136,   3,   3],
#        [  0,   0,   5,   2, 147,   0],
#        [  0,   5,   2,   4,   2, 136]])

# %%
confusion_matrix = pd.crosstab(df['label'], df['pred'], rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True, fmt="d")

# %%
pd.set_option('display.max_colwidth', -1)
df[df['label'] != df['pred']].sort_values(['pred_score'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
#         label label_sentiment       id  \
# 308  books     pos             41.txt
# 677  books     neg             575.txt
# 286  software  neg             425.txt
# 371  health    neg             946.txt
# 585  music     neg             206.txt
# 480  camera    pos             233.txt
# 648  health    neg             376.txt
# 600  software  pos             617.txt
# 138  health    pos             97.txt
# 289  software  pos             988.txt
# 550  music     neg             396.txt
# 117  health    pos             770.txt
# 576  software  neg             120.txt
# 389  health    pos             155.txt
# 342  health    neg             910.txt
# 333  dvd       neg             417.txt
# ...
